# %%
# import the pymongo library - this is the Python driver!
import pymongo

# replace "uri" with your Atlas URI string - should look like mongodb+srv://...
uri = "mongodb+srv://m220student:1993827jhd@mflix.s1mof.mongodb.net/<dbname>?retryWrites=true&w=majority"
client = pymongo.MongoClient(uri)
mflix = client.sample_mflix

# movies is our collection handle - it refers to the sample_mflix.movies collection
movies = mflix.movies

# %%
# find one document in the "movies" collection - does not matter which one
movies.find_one()
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'),
#  'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#  'genres': ['Short'],
#  'runtime': 1,
#  'cast': ['Charles Kayser', 'John Ott'],
#  'num_mflix_comments': 1,
#  'title': 'Blacksmith Scene',
#  'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#  'countries': ['USA'],
#  'released': datetime.datetime(1893, 5, 9, 0, 0),
#  'directors': ['William K.L. Dickson'],
#  'rated': 'UNRATED',
#  'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#  'lastupdated': '2015-08-26 00:03:50.133000000',
#  'year': 1893,
#  'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5},
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184, 'meter': 32},
#   'lastUpdated': datetime.datetime(2015, 6, 28, 18, 34, 9)}}

# %%
# find one document in the "movies" collection - must have "Salma Hayek" in the "cast"
countries = ["China"]

# %%
list(movies.find({"countries": {"$in": countries}},{"title":1,"_id":1}))
# Out:
# [{'_id': ObjectId('573a1393f29313caabcde53f'), 'title': 'Wuya yu maque'},
#  {'_id': ObjectId('573a1394f29313caabce03f0'), 'title': 'Zhu Fu'},
#  {'_id': ObjectId('573a1395f29313caabce29cd'), 'title': 'The Monkey King'},
#  {'_id': ObjectId('573a1397f29313caabce74d3'), 'title': 'The Shaolin Temple'},
#  {'_id': ObjectId('573a1398f29313caabce91a1'), 'title': 'Yellow Earth'},
#  {'_id': ObjectId('573a1398f29313caabce9f91'),
#   'title': 'The Great Wall Is a Great Wall'},
#  {'_id': ObjectId('573a1398f29313caabcea14f'),
#   'title': 'Martial Arts of Shaolin'},
#  {'_id': ObjectId('573a1398f29313caabcea702'), 'title': 'Hai zi wang'},
#  {'_id': ObjectId('573a1398f29313caabcea73e'), 'title': 'Red Sorghum'},
#  {'_id': ObjectId('573a1398f29313caabcea7f9'), 'title': 'The Last Emperor'},
#  {'_id': ObjectId('573a1398f29313caabcebd69'),
#   'title': 'Bethune: The Making of a Hero'},
#  {'_id': ObjectId('573a1399f29313caabcec062'), 'title': 'Ju Dou'},
#  {'_id': ObjectId('573a1399f29313caabcec624'), 'title': 'Bian zou bian chang'},
#  {'_id': ObjectId('573a1399f29313caabcec6fb'),
#   'title': 'Raise the Red Lantern'},
#  {'_id': ObjectId('573a1399f29313caabced475'), 'title': 'The Story of Qiu Ju'},
#  {'_id': ObjectId('573a1399f29313caabced8b4'),
#   'title': 'Farewell My Concubine'},
#  {'_id': ObjectId('573a1399f29313caabced8e1'), 'title': 'Beijing za zhong'},
#  {'_id': ObjectId('573a1399f29313caabceda59'), 'title': 'Dongchun de rizi'},
#  {'_id': ObjectId('573a1399f29313caabcedc60'), 'title': 'The Joy Luck Club'},
#  {'_id': ObjectId('573a1399f29313caabcedcac'), 'title': 'The Blue Kite'},
#  {'_id': ObjectId('573a1399f29313caabcee3c8'),
#   'title': 'Bei kao bei, lian dui lian'},
#  {'_id': ObjectId('573a1399f29313caabcee705'), 'title': 'To Live'},
#  {'_id': ObjectId('573a1399f29313caabcee998'),
#   'title': 'Red Firecracker, Green Firecracker'},
#  {'_id': ObjectId('573a139af29313caabcef9a4'), 'title': 'Shanghai Triad'},
#  {'_id': ObjectId('573a139af29313caabcefc4a'), 'title': 'The King of Masks'},
#  {'_id': ObjectId('573a139af29313caabcefe80'), 'title': 'Temptress Moon'},
#  {'_id': ObjectId('573a139af29313caabcf0782'),
#   'title': 'In the Mood for Love'},
#  {'_id': ObjectId('573a139af29313caabcf08c1'),
#   'title': 'East Palace West Palace'},
#  {'_id': ObjectId('573a139af29313caabcf0e15'), 'title': 'Warriors of Virtue'},
#  {'_id': ObjectId('573a139cf29313caabcf6610'), 'title': 'Pick Pocket'},
#  {'_id': ObjectId('573a139df29313caabcfad15'),
#   'title': 'The Emperor and the Assassin'},
#  {'_id': ObjectId('573a139ff29313caabd0145e'),
#   'title': 'Crouching Tiger, Hidden Dragon'},
#  {'_id': ObjectId('573a13a0f29313caabd05b01'), 'title': 'Not One Less'},
#  {'_id': ObjectId('573a13a1f29313caabd06822'), 'title': '2046'},
#  {'_id': ObjectId('573a13a1f29313caabd0720e'), 'title': 'Shower'},
#  {'_id': ObjectId('573a13a2f29313caabd0bb51'), 'title': 'Suzhou River'},
#  {'_id': ObjectId('573a13a2f29313caabd0bc33'), 'title': 'The Road Home'},
#  {'_id': ObjectId('573a13a2f29313caabd0befa'), 'title': 'Suzhou River'},
#  {'_id': ObjectId('573a13a3f29313caabd0c99c'), 'title': 'Shadow Magic'},
#  {'_id': ObjectId('573a13a3f29313caabd0cbf5'), 'title': 'Spicy Love Soup'},
#  {'_id': ObjectId('573a13a3f29313caabd0e0b9'), 'title': 'Pavilion of Women'},
#  {'_id': ObjectId('573a13a3f29313caabd0e565'),
#   'title': 'Devils on the Doorstep'},
#  {'_id': ObjectId('573a13a3f29313caabd0e6af'),
#   'title': 'In the Mood for Love'},
#  {'_id': ObjectId('573a13a3f29313caabd0f014'),
#   'title': 'In the Mood for Love'},
#  {'_id': ObjectId('573a13a4f29313caabd0fa14'), 'title': 'Time and Tide'},
#  {'_id': ObjectId('573a13a4f29313caabd1163c'), 'title': 'Platform'},
#  {'_id': ObjectId('573a13a5f29313caabd1536b'), 'title': 'The Warrior'},
#  {'_id': ObjectId('573a13a5f29313caabd158ce'), 'title': 'Beijing Bicycle'},
#  {'_id': ObjectId('573a13a5f29313caabd15b55'), 'title': 'The Warrior'},
#  {'_id': ObjectId('573a13a6f29313caabd17ce3'), 'title': 'Shaolin Soccer'},
#  {'_id': ObjectId('573a13a6f29313caabd183bb'), 'title': 'Da wan'},
#  {'_id': ObjectId('573a13a6f29313caabd18f3c'),
#   'title': 'Balzac and the Little Chinese Seamstress'},
#  {'_id': ObjectId('573a13a6f29313caabd1933a'), 'title': 'Lan Yu'},
#  {'_id': ObjectId('573a13a6f29313caabd19980'), 'title': 'The Touch'},
#  {'_id': ObjectId('573a13a7f29313caabd1aa6d'), 'title': 'Quitting'},
#  {'_id': ObjectId('573a13a7f29313caabd1b110'), 'title': 'Hero'},
#  {'_id': ObjectId('573a13a7f29313caabd1bd34'), 'title': 'Happy Times'},
#  {'_id': ObjectId('573a13a8f29313caabd1c30f'),
#   'title': 'Ten Minutes Older: The Trumpet'},
#  {'_id': ObjectId('573a13a9f29313caabd1f398'), 'title': 'Fish and Elephant'},
#  {'_id': ObjectId('573a13a9f29313caabd1f42d'),
#   'title': 'Mission: Impossible III'},
#  {'_id': ObjectId('573a13a9f29313caabd1f48a'), 'title': 'Unknown Pleasures'},
#  {'_id': ObjectId('573a13aaf29313caabd22bc4'), 'title': 'Together with You'},
#  {'_id': ObjectId('573a13aaf29313caabd22c7e'),
#   'title': 'Springtime in a Small Town'},
#  {'_id': ObjectId('573a13acf29313caabd272a3'), 'title': 'Blind Shaft'},
#  {'_id': ObjectId('573a13acf29313caabd27dc1'), 'title': 'Zhou Yu de huo che'},
#  {'_id': ObjectId('573a13acf29313caabd28247'),
#   'title': 'Feelings of Mountains and Waters'},
#  {'_id': ObjectId('573a13adf29313caabd29fd5'), 'title': 'Purple Butterfly'},
#  {'_id': ObjectId('573a13adf29313caabd2a7d5'), 'title': 'Spring Subway'},
#  {'_id': ObjectId('573a13adf29313caabd2a96e'), 'title': 'The Myth'},
#  {'_id': ObjectId('573a13adf29313caabd2b557'), 'title': 'Infernal Affairs 2'},
#  {'_id': ObjectId('573a13adf29313caabd2b765'), 'title': 'Jurassic World'},
#  {'_id': ObjectId('573a13adf29313caabd2bc8e'), 'title': 'Jasmine Flower'},
#  {'_id': ObjectId('573a13adf29313caabd2becd'), 'title': 'Big Bird in China'},
#  {'_id': ObjectId('573a13aef29313caabd2c465'), 'title': 'Kung Fu Hustle'},
#  {'_id': ObjectId('573a13aef29313caabd2c8a3'), 'title': 'Running on Karma'},
#  {'_id': ObjectId('573a13aef29313caabd2c923'),
#   'title': 'Warriors of Heaven and Earth'},
#  {'_id': ObjectId('573a13aef29313caabd2c93e'), 'title': 'Infernal Affairs 3'},
#  {'_id': ObjectId('573a13aef29313caabd2e941'), 'title': 'Green Tea'},
#  {'_id': ObjectId('573a13aef29313caabd2f028'), 'title': 'The White Countess'},
#  {'_id': ObjectId('573a13aff29313caabd2f16a'),
#   'title': 'House of Flying Daggers'},
#  {'_id': ObjectId('573a13aff29313caabd2f524'), 'title': 'New Police Story'},
#  {'_id': ObjectId('573a13aff29313caabd2f797'), 'title': 'Mountain Patrol'},
#  {'_id': ObjectId('573a13aff29313caabd2f97c'),
#   'title': 'The Constant Gardener'},
#  {'_id': ObjectId('573a13aff29313caabd30230'),
#   'title': 'Tie Xi Qu: West of the Tracks'},
#  {'_id': ObjectId('573a13aff29313caabd31b2a'), 'title': 'Smile'},
#  {'_id': ObjectId('573a13aff29313caabd31f9d'), 'title': 'Blade of Kings'},
#  {'_id': ObjectId('573a13aff29313caabd3225f'),
#   'title': 'Godzilla: Final Wars'},
#  {'_id': ObjectId('573a13b0f29313caabd32bd9'), 'title': 'Sunflower'},
#  {'_id': ObjectId('573a13b1f29313caabd35aaa'), 'title': 'Chinaman'},
#  {'_id': ObjectId('573a13b1f29313caabd35d6d'), 'title': 'Breaking News'},
#  {'_id': ObjectId('573a13b1f29313caabd35f17'), 'title': 'Throw Down'},
#  {'_id': ObjectId('573a13b1f29313caabd364d2'), 'title': 'Jade Warrior'},
#  {'_id': ObjectId('573a13b1f29313caabd368e5'), 'title': 'The Promise'},
#  {'_id': ObjectId('573a13b1f29313caabd3701a'), 'title': 'The Kite Runner'},
#  {'_id': ObjectId('573a13b1f29313caabd37c5f'), 'title': 'The World'},
#  {'_id': ObjectId('573a13b1f29313caabd3809f'), 'title': 'Electric Shadows'},
#  {'_id': ObjectId('573a13b2f29313caabd385c9'), 'title': 'Red Cliff'},
#  {'_id': ObjectId('573a13b2f29313caabd392d6'), 'title': 'Seven Swords'},
#  {'_id': ObjectId('573a13b3f29313caabd3b262'),
#   'title': 'Riding Alone for Thousands of Miles'},
#  {'_id': ObjectId('573a13b3f29313caabd3ba9a'), 'title': 'Initial D'},
#  {'_id': ObjectId('573a13b3f29313caabd3bb87'),
#   'title': 'A World Without Thieves'},
#  {'_id': ObjectId('573a13b3f29313caabd3d2d6'), 'title': 'Fearless'},
#  {'_id': ObjectId('573a13b3f29313caabd3d56e'), 'title': 'The Painted Veil'},
#  {'_id': ObjectId('573a13b4f29313caabd3f42b'), 'title': 'Perhaps Love'},
#  {'_id': ObjectId('573a13b4f29313caabd3facb'), 'title': 'Shanghai Dreams'},
#  {'_id': ObjectId('573a13b4f29313caabd3fb5c'), 'title': 'About Love'},
#  {'_id': ObjectId('573a13b4f29313caabd40cfc'), 'title': 'Pirated Copy'},
#  {'_id': ObjectId('573a13b4f29313caabd40e14'), 'title': 'Mongolian Ping Pong'},
#  {'_id': ObjectId('573a13b4f29313caabd41c4a'), 'title': 'The Banquet'},
#  {'_id': ObjectId('573a13b5f29313caabd4296a'), 'title': 'Shanghai Kiss'},
#  {'_id': ObjectId('573a13b5f29313caabd4367b'),
#   'title': 'The Red Detachment of Women'},
#  {'_id': ObjectId('573a13b5f29313caabd4397a'),
#   'title': 'Curse of the Golden Flower'},
#  {'_id': ObjectId('573a13b6f29313caabd45cd4'), 'title': 'Dragon Tiger Gate'},
#  {'_id': ObjectId('573a13b6f29313caabd467f5'),
#   'title': 'Battle of the Warriors'},
#  {'_id': ObjectId('573a13b6f29313caabd48089'), 'title': 'Little Red Flowers'},
#  {'_id': ObjectId('573a13b6f29313caabd48f38'),
#   'title': 'The Secret of the Magic Gourd'},
#  {'_id': ObjectId('573a13b7f29313caabd4a4f6'), 'title': 'My Blueberry Nights'},
#  {'_id': ObjectId('573a13b7f29313caabd4a745'), 'title': 'The Sun Also Rises'},
#  {'_id': ObjectId('573a13b7f29313caabd4a855'), 'title': 'Samsara'},
#  {'_id': ObjectId('573a13b8f29313caabd4b6eb'), 'title': 'Getting Home'},
#  {'_id': ObjectId('573a13b8f29313caabd4c1d0'), 'title': 'Summer Palace'},
#  {'_id': ObjectId('573a13b8f29313caabd4d127'), 'title': 'Lust, Caution'},
#  {'_id': ObjectId('573a13b9f29313caabd4e268'), 'title': 'The Matrimony'},
#  {'_id': ObjectId('573a13baf29313caabd4feac'), 'title': 'Crazy Stone'},
#  {'_id': ObjectId('573a13baf29313caabd50326'), 'title': 'Triangle'},
#  {'_id': ObjectId('573a13baf29313caabd507ec'), 'title': 'Kung Fu Dunk'},
#  {'_id': ObjectId('573a13baf29313caabd50a79'), 'title': 'Silver Medallist'},
#  {'_id': ObjectId('573a13baf29313caabd50dbb'),
#   'title': "I Don't Want to Sleep Alone"},
#  {'_id': ObjectId('573a13baf29313caabd51130'),
#   'title': 'The Mummy: Tomb of the Dragon Emperor'},
#  {'_id': ObjectId('573a13baf29313caabd51199'), 'title': 'Still Life'},
#  {'_id': ObjectId('573a13baf29313caabd5126a'), 'title': 'Still Life'},
#  {'_id': ObjectId('573a13baf29313caabd517c1'),
#   'title': 'The Forbidden Kingdom'},
#  {'_id': ObjectId('573a13bbf29313caabd52571'), 'title': 'Assembly'},
#  {'_id': ObjectId('573a13bbf29313caabd526e6'),
#   'title': 'Three Kingdoms: Resurrection of the Dragon'},
#  {'_id': ObjectId('573a13bbf29313caabd52d0a'),
#   'title': 'The Children of Huang Shi'},
#  {'_id': ObjectId('573a13bbf29313caabd5322f'), 'title': 'Missing'},
#  {'_id': ObjectId('573a13bbf29313caabd53e4e'), 'title': 'The Warlords'},
#  {'_id': ObjectId('573a13bcf29313caabd55c3c'), 'title': 'Lost in Beijing'},
#  {'_id': ObjectId('573a13bcf29313caabd55c86'), 'title': "Tuya's Marriage"},
#  {'_id': ObjectId('573a13bdf29313caabd58286'), 'title': 'Flash Point'},
#  {'_id': ObjectId('573a13bdf29313caabd584c5'), 'title': 'Invisible Target'},
#  {'_id': ObjectId('573a13bdf29313caabd5864b'), 'title': 'Flash Point'},
#  {'_id': ObjectId('573a13bdf29313caabd599ae'), 'title': 'Blind Mountain'},
#  {'_id': ObjectId('573a13bdf29313caabd5a2c2'), 'title': 'Inseparable'},
#  {'_id': ObjectId('573a13bdf29313caabd5a33b'), 'title': 'Night Train'},
#  {'_id': ObjectId('573a13bef29313caabd5b726'), 'title': 'Warm Spring'},
#  {'_id': ObjectId('573a13bef29313caabd5b81b'), 'title': 'Painted Skin'},
#  {'_id': ObjectId('573a13bff29313caabd5df99'), 'title': 'Please Vote for Me'},
#  {'_id': ObjectId('573a13bff29313caabd5e328'), 'title': '24 City'},
#  {'_id': ObjectId('573a13bff29313caabd5f155'),
#   'title': 'Detective Dee: Mystery of the Phantom Flame'},
#  {'_id': ObjectId('573a13bff29313caabd5f168'),
#   'title': 'Detective Dee: Mystery of the Phantom Flame'},
#  {'_id': ObjectId('573a13bff29313caabd5f21b'),
#   'title': 'City of Life and Death'},
#  {'_id': ObjectId('573a13bff29313caabd5f2a3'),
#   'title': 'City of War: The Story of John Rabe'},
#  {'_id': ObjectId('573a13c0f29313caabd60d3d'), 'title': 'The Karate Kid'},
#  {'_id': ObjectId('573a13c0f29313caabd60fca'), 'title': 'Connected'},
#  {'_id': ObjectId('573a13c0f29313caabd62381'), 'title': 'W.'},
#  {'_id': ObjectId('573a13c0f29313caabd63077'),
#   'title': 'An Empress and the Warriors'},
#  {'_id': ObjectId('573a13c1f29313caabd652bb'), 'title': 'Ip Man'},
#  {'_id': ObjectId('573a13c2f29313caabd684d8'), 'title': 'Looper'},
#  {'_id': ObjectId('573a13c3f29313caabd69c74'), 'title': 'Iron Man 3'},
#  {'_id': ObjectId('573a13c3f29313caabd69ef1'), 'title': "Sophie's Revenge"},
#  {'_id': ObjectId('573a13c3f29313caabd6a2a2'),
#   'title': 'Mulan: Rise of a Warrior'},
#  {'_id': ObjectId('573a13c3f29313caabd6b4c1'), 'title': 'Red Cliff II'},
#  {'_id': ObjectId('573a13c4f29313caabd6b8a0'), 'title': 'If You Are the One'},
#  {'_id': ObjectId('573a13c4f29313caabd6d0dc'), 'title': 'Overheard'},
#  {'_id': ObjectId('573a13c4f29313caabd6df6d'), 'title': 'Empire of Silver'},
#  {'_id': ObjectId('573a13c5f29313caabd6fe45'), 'title': 'Ip Man 2'},
#  {'_id': ObjectId('573a13c5f29313caabd705f8'), 'title': 'Aftershock'},
#  {'_id': ObjectId('573a13c5f29313caabd70a6f'), 'title': 'Confucius'},
#  {'_id': ObjectId('573a13c5f29313caabd71027'),
#   'title': 'Bodyguards and Assassins'},
#  {'_id': ObjectId('573a13c6f29313caabd71743'), 'title': 'The Flowers of War'},
#  {'_id': ObjectId('573a13c6f29313caabd72978'), 'title': 'Chinese Zodiac'},
#  {'_id': ObjectId('573a13c6f29313caabd72bd6'), 'title': 'True Legend'},
#  {'_id': ObjectId('573a13c6f29313caabd72ee1'),
#   'title': 'A Woman, a Gun and a Noodle Shop'},
#  {'_id': ObjectId('573a13c6f29313caabd73594'), 'title': 'The Message'},
#  {'_id': ObjectId('573a13c7f29313caabd73979'),
#   'title': 'The Founding of a Republic'},
#  {'_id': ObjectId('573a13c7f29313caabd73ea7'), 'title': '14 Blades'},
#  {'_id': ObjectId('573a13c7f29313caabd74dee'),
#   'title': 'Legend of the Fist: The Return of Chen Zhen'},
#  {'_id': ObjectId('573a13c7f29313caabd74df8'), 'title': "No Man's Land"},
#  {'_id': ObjectId('573a13c7f29313caabd7520e'), 'title': 'Reign of Assassins'},
#  {'_id': ObjectId('573a13c7f29313caabd754ac'), 'title': 'The Grandmaster'},
#  {'_id': ObjectId('573a13c7f29313caabd7647f'), 'title': 'Looking for Jackie'},
#  {'_id': ObjectId('573a13c8f29313caabd76a48'), 'title': 'Young Bruce Lee'},
#  {'_id': ObjectId('573a13c8f29313caabd76b49'), 'title': 'Looking for Jackie'},
#  {'_id': ObjectId('573a13c8f29313caabd77a92'), 'title': 'Ocean Heaven'},
#  {'_id': ObjectId('573a13c8f29313caabd78a6b'), 'title': 'Last Train Home'},
#  {'_id': ObjectId('573a13c9f29313caabd793be'),
#   'title': 'Xianshi shi guoqu de weilai'},
#  {'_id': ObjectId('573a13c9f29313caabd7a469'), 'title': 'Let the Bullets Fly'},
#  {'_id': ObjectId('573a13c9f29313caabd7a484'), 'title': 'Shaolin'},
#  {'_id': ObjectId('573a13c9f29313caabd7a501'), 'title': 'Dirty Business'},
#  {'_id': ObjectId('573a13c9f29313caabd7b244'),
#   'title': 'Snow Flower and the Secret Fan'},
#  {'_id': ObjectId('573a13caf29313caabd7c415'), 'title': 'The Flowers of War'},
#  {'_id': ObjectId('573a13caf29313caabd7c425'),
#   'title': 'Under the Hawthorn Tree'},
#  {'_id': ObjectId('573a13cbf29313caabd80a42'), 'title': 'The Woodmans'},
#  {'_id': ObjectId('573a13cbf29313caabd81378'), 'title': 'Racing Extinction'},
#  {'_id': ObjectId('573a13ccf29313caabd81adf'),
#   'title': 'Mr. and Mrs. Incredible'},
#  {'_id': ObjectId('573a13ccf29313caabd83181'), 'title': 'I Wish I Knew'},
#  {'_id': ObjectId('573a13ccf29313caabd8320c'), 'title': 'Love in Disguise'},
#  {'_id': ObjectId('573a13ccf29313caabd833ae'), 'title': 'The Lost Bladesman'},
#  {'_id': ObjectId('573a13cdf29313caabd849c1'), 'title': 'Looking for Jackie'},
#  {'_id': ObjectId('573a13cdf29313caabd8606d'),
#   'title': 'Flying Swords of Dragon Gate'},
#  {'_id': ObjectId('573a13cef29313caabd86ddc'), 'title': 'Catching the Sun'},
#  {'_id': ObjectId('573a13cef29313caabd86e82'),
#   'title': 'Beginning of the Great Revival'},
#  {'_id': ObjectId('573a13cef29313caabd872eb'), 'title': '33 Postcards'},
#  {'_id': ObjectId('573a13cef29313caabd88223'), 'title': 'The Monkey King'},
#  {'_id': ObjectId('573a13cef29313caabd882a1'), 'title': 'Dragon'},
#  {'_id': ObjectId('573a13cff29313caabd88822'),
#   'title': 'The Butcher, the Chef, and the Swordsman'},
#  {'_id': ObjectId('573a13cff29313caabd888eb'), 'title': 'Gang de qin'},
#  {'_id': ObjectId('573a13cff29313caabd88da1'), 'title': 'Sacrifice'},
#  {'_id': ObjectId('573a13cff29313caabd8a575'), 'title': 'Buddha Mountain'},
#  {'_id': ObjectId('573a13d0f29313caabd8bdd2'), 'title': '1911'},
#  {'_id': ObjectId('573a13d2f29313caabd922bd'), 'title': 'The Guillotines'},
#  {'_id': ObjectId('573a13d2f29313caabd92945'), 'title': 'Overheard 2'},
#  {'_id': ObjectId('573a13d2f29313caabd92fb2'),
#   'title': 'The Sorcerer and the White Snake'},
#  {'_id': ObjectId('573a13d2f29313caabd933c6'), 'title': 'Sien nui yau wan'},
#  {'_id': ObjectId('573a13d3f29313caabd93e84'), 'title': 'The Great Magician'},
#  {'_id': ObjectId('573a13d3f29313caabd93eeb'),
#   'title': 'Xianshi shi guoqu de weilai'},
#  {'_id': ObjectId('573a13d4f29313caabd99ec3'), 'title': 'Tai Chi Zero'},
#  {'_id': ObjectId('573a13d5f29313caabd9c565'), 'title': 'Journey to the West'},
#  {'_id': ObjectId('573a13d5f29313caabd9d75a'), 'title': '11 Flowers'},
#  {'_id': ObjectId('573a13d6f29313caabd9e801'), 'title': 'The Viral Factor'},
#  {'_id': ObjectId('573a13d6f29313caabd9edd1'), 'title': 'Shanghai Calling'},
#  {'_id': ObjectId('573a13d6f29313caabd9ef20'), 'title': 'Dangerous Liaisons'},
#  {'_id': ObjectId('573a13d6f29313caabd9fae9'), 'title': 'China Heavyweight'},
#  {'_id': ObjectId('573a13d6f29313caabd9fd16'), 'title': 'Starry Starry Night'},
#  {'_id': ObjectId('573a13d6f29313caabda0638'),
#   'title': 'Escape Fire: The Fight to Rescue American Healthcare'},
#  {'_id': ObjectId('573a13d7f29313caabda16c0'), 'title': 'The Bullet Vanishes'},
#  {'_id': ObjectId('573a13d7f29313caabda1952'),
#   'title': 'Transformers: Age of Extinction'},
#  {'_id': ObjectId('573a13d7f29313caabda1d25'), 'title': 'Back to 1942'},
#  {'_id': ObjectId('573a13d7f29313caabda2064'), 'title': 'Special ID'},
#  {'_id': ObjectId('573a13d7f29313caabda215e'), 'title': 'Pixels'},
#  {'_id': ObjectId('573a13d7f29313caabda3e96'), 'title': 'High Tech, Low Life'},
#  {'_id': ObjectId('573a13d7f29313caabda4a4b'), 'title': 'Drug War'},
#  {'_id': ObjectId('573a13d7f29313caabda4da5'), 'title': 'Finding Mr. Right'},
#  {'_id': ObjectId('573a13d8f29313caabda6d89'), 'title': 'Love'},
#  {'_id': ObjectId('573a13d8f29313caabda7337'), 'title': 'Transcendence'},
#  {'_id': ObjectId('573a13d9f29313caabda8de8'), 'title': 'Love in the Buff'},
#  {'_id': ObjectId('573a13daf29313caabdab37d'),
#   'title': 'American Dreams in China'},
#  {'_id': ObjectId('573a13daf29313caabdabe0b'),
#   'title': 'Once Upon a Time in Shanghai'},
#  {'_id': ObjectId('573a13daf29313caabdabe62'), 'title': 'Design of Death'},
#  {'_id': ObjectId('573a13daf29313caabdac37e'), 'title': 'Tai Chi Hero'},
#  {'_id': ObjectId('573a13daf29313caabdacaa5'), 'title': 'Death by China'},
#  {'_id': ObjectId('573a13dbf29313caabdae7c8'), 'title': 'Blind Detective'},
#  {'_id': ObjectId('573a13dbf29313caabdafb40'), 'title': 'Croczilla'},
#  {'_id': ObjectId('573a13dcf29313caabdb0cf8'), 'title': 'Mystery'},
#  {'_id': ObjectId('573a13dcf29313caabdb0f92'),
#   'title': 'Painted Skin: The Resurrection'},
#  {'_id': ObjectId('573a13dcf29313caabdb1d88'), 'title': 'Bian jing feng yun'},
#  {'_id': ObjectId('573a13ddf29313caabdb37c0'),
#   'title': 'Black & White Episode 1: The Dawn of Assault'},
#  {'_id': ObjectId('573a13ddf29313caabdb37d2'), 'title': 'The Human Scale'},
#  {'_id': ObjectId('573a13ddf29313caabdb3a66'), 'title': 'Red Obsession'},
#  {'_id': ObjectId('573a13ddf29313caabdb4d5b'), 'title': 'The Last Tycoon'},
#  {'_id': ObjectId('573a13ddf29313caabdb4dd4'), 'title': 'Lost in Thailand'},
#  {'_id': ObjectId('573a13def29313caabdb627d'), 'title': 'All Eyes and Ears'},
#  {'_id': ObjectId('573a13def29313caabdb6438'),
#   'title': 'Where the Trail Ends'},
#  {'_id': ObjectId('573a13dff29313caabdb7844'), 'title': 'Iceman'},
#  {'_id': ObjectId('573a13dff29313caabdb7cec'), 'title': 'Seoul Searching'},
#  {'_id': ObjectId('573a13e1f29313caabdbbce8'), 'title': 'Fury'},
#  {'_id': ObjectId('573a13e1f29313caabdbd20c'), 'title': 'So Young'},
#  {'_id': ObjectId('573a13e2f29313caabdbeedc'), 'title': 'Fallen City'},
#  {'_id': ObjectId('573a13e2f29313caabdbf549'), 'title': 'A Touch of Sin'},
#  {'_id': ObjectId('573a13e3f29313caabdc070f'), 'title': 'The Rooftop'},
#  {'_id': ObjectId('573a13e3f29313caabdc0a0c'), 'title': 'Wolf Totem'},
#  {'_id': ObjectId('573a13e3f29313caabdc0d76'), 'title': 'Over Your Dead Body'},
#  {'_id': ObjectId('573a13e4f29313caabdc210f'), 'title': 'Kung Fu Killer'},
#  {'_id': ObjectId('573a13e4f29313caabdc244f'), 'title': 'The White Storm'},
#  {'_id': ObjectId('573a13e5f29313caabdc2ee3'), 'title': 'The Nightingale'},
#  {'_id': ObjectId('573a13e5f29313caabdc33f5'), 'title': '9-Man'},
#  {'_id': ObjectId('573a13e5f29313caabdc36df'),
#   'title': 'Young Detective Dee: Rise of the Sea Dragon'},
#  {'_id': ObjectId('573a13e5f29313caabdc3d2d'), 'title': 'Unbeatable'},
#  {'_id': ObjectId('573a13e5f29313caabdc426f'),
#   'title': "Sur le chemin de l'ècole"},
#  {'_id': ObjectId('573a13e6f29313caabdc4e81'), 'title': 'The Crossing'},
#  {'_id': ObjectId('573a13e7f29313caabdc751f'), 'title': 'Overheard 3'},
#  {'_id': ObjectId('573a13e7f29313caabdc7761'), 'title': 'Coming Home'},
#  {'_id': ObjectId('573a13e8f29313caabdc8fc5'),
#   'title': 'Bei tou zou de na wu nian'},
#  {'_id': ObjectId('573a13e9f29313caabdcb88f'), 'title': 'The Wrath of Vajra'},
#  {'_id': ObjectId('573a13e9f29313caabdcd171'), 'title': 'Women Who Flirt'},
#  {'_id': ObjectId('573a13e9f29313caabdce01f'), 'title': 'Firestorm'},
#  {'_id': ObjectId('573a13e9f29313caabdce0fb'), 'title': 'Blue Sky Bones'},
#  {'_id': ObjectId('573a13ecf29313caabdd1e08'),
#   'title': 'The White Haired Witch of Lunar Kingdom'},
#  {'_id': ObjectId('573a13ecf29313caabdd205d'), 'title': 'Rise of the Legend'},
#  {'_id': ObjectId('573a13ecf29313caabdd2091'), 'title': 'Blind Massage'},
#  {'_id': ObjectId('573a13ecf29313caabdd209e'),
#   'title': 'Black Coal, Thin Ice'},
#  {'_id': ObjectId('573a13edf29313caabdd3305'), 'title': 'The Midnight After'},
#  {'_id': ObjectId('573a13edf29313caabdd3563'), 'title': 'The Assassin'},
#  {'_id': ObjectId('573a13edf29313caabdd3741'), 'title': 'That Demon Within'},
#  {'_id': ObjectId('573a13edf29313caabdd46e9'), 'title': 'Wolf Warrior'},
#  {'_id': ObjectId('573a13eef29313caabdd5fef'), 'title': 'Sweet Alibis'},
#  {'_id': ObjectId('573a13eff29313caabdd88e1'), 'title': 'Dragon Blade'},
#  {'_id': ObjectId('573a13f0f29313caabdd9e50'), 'title': 'The Great Hypnotist'},
#  {'_id': ObjectId('573a13f0f29313caabdda7ac'),
#   'title': 'Mountains May Depart'},
#  {'_id': ObjectId('573a13f2f29313caabddda4f'), 'title': 'A Fool'},
#  {'_id': ObjectId('573a13f2f29313caabdddbbc'), 'title': 'Tiny Times 3.0'},
#  {'_id': ObjectId('573a13f3f29313caabdde4dd'), 'title': 'Chuang ru zhe'},
#  {'_id': ObjectId('573a13f3f29313caabdde6e3'), 'title': 'The Continent'},
#  {'_id': ObjectId('573a13f3f29313caabddead0'), 'title': 'But Always'},
#  {'_id': ObjectId('573a13f3f29313caabddf50c'),
#   'title': 'The Taking of Tiger Mountain'},
#  {'_id': ObjectId('573a13f3f29313caabddf75e'), 'title': 'My Old Classmate'},
#  {'_id': ObjectId('573a13f4f29313caabde0ebe'), 'title': 'Xiu chun dao'},
#  {'_id': ObjectId('573a13f4f29313caabde1b81'), 'title': 'The Chinese Mayor'},
#  {'_id': ObjectId('573a13f4f29313caabde218e'),
#   'title': 'Somewhere Only We Know'},
#  {'_id': ObjectId('573a13f6f29313caabde581e'), 'title': 'Insanity'},
#  {'_id': ObjectId('573a13f9f29313caabdeaa87'), 'title': 'Kaili Blues'},
#  {'_id': ObjectId('573a13f9f29313caabdeb0d7'),
#   'title': 'Monkey King: Hero Is Back'}]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-c84e34a38467> in <module>
# ----> 1 list(movies.find())
#
# AttributeError: 'Cursor' object has no attribute 'find'

# %%
print(len(list(movies.find( { 'countries': { '$in': countries }}))))
# Out:
# 303

# %%
list(movies.find().limit(1))
# Out:
# [{'_id': ObjectId('573a1390f29313caabcd4135'),
#   'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#   'genres': ['Short'],
#   'runtime': 1,
#   'cast': ['Charles Kayser', 'John Ott'],
#   'num_mflix_comments': 1,
#   'title': 'Blacksmith Scene',
#   'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#   'countries': ['USA'],
#   'released': datetime.datetime(1893, 5, 9, 0, 0),
#   'directors': ['William K.L. Dickson'],
#   'rated': 'UNRATED',
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-26 00:03:50.133000000',
#   'year': 1893,
#   'imdb': {'rating': 6.2, 'votes': 1189, 'id': 5},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 184, 'meter': 32},
#    'lastUpdated': datetime.datetime(2015, 6, 28, 18, 34, 9)}}]

# %%
# find all the documents in the "movies" collection with "Salma Hayek" in the "cast"
# this returns a cursor, which IS a Python iterable, but is NOT a document!
movies.find( { "cast": "Salma Hayek" } )

# %%
# return the count of movies with "Salma Hayek" in the "cast"
movies.find( { "cast": "Salma Hayek" } ).count()

# %%
# find all movies with Salma Hayek
# then pretty print
cursor = movies.find( { "cast": "Salma Hayek" } )
from bson.json_util import dumps
print(dumps(cursor, indent=2))

# %%
# find all movies with Salma Hayek, but only project the "_id" and "title" fields
cursor = movies.find( { "cast": "Salma Hayek" }, { "title": 1 } )
print(dumps(cursor, indent=2))

# %%
# find all movies with Salma Hayek, but only project the "title" field
cursor = movies.find( { "cast": "Salma Hayek" }, { "title": 1, "_id": 0 } )
print(dumps(cursor, indent=2))
